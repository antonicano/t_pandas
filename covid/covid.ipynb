# %%
import pandas as pd
df = pd.read_csv('country_vaccinations.csv')
df_population = pd.read_csv('world_population.csv')

# %%
df
# Out:
#            country iso_code        date  total_vaccinations  \
# 0      Afghanistan      AFG  2021-02-22                 0.0
# 1      Afghanistan      AFG  2021-02-23                 NaN
# 2      Afghanistan      AFG  2021-02-24                 NaN
# 3      Afghanistan      AFG  2021-02-25                 NaN
# 4      Afghanistan      AFG  2021-02-26                 NaN
# ...            ...      ...         ...                 ...
# 86507     Zimbabwe      ZWE  2022-03-25           8691642.0
# 86508     Zimbabwe      ZWE  2022-03-26           8791728.0
# 86509     Zimbabwe      ZWE  2022-03-27           8845039.0
# 86510     Zimbabwe      ZWE  2022-03-28           8934360.0
# 86511     Zimbabwe      ZWE  2022-03-29           9039729.0
#
#        people_vaccinated  people_fully_vaccinated  daily_vaccinations_raw  \
# 0                    0.0                      NaN                     NaN
# 1                    NaN                      NaN                     NaN
# ...

# %%
vaccinations_mean = df.groupby('country')['total_vaccinations'].mean()
vaccinations_mean
# Out:
# country
# Afghanistan          2.566118e+06
# Albania              1.191695e+06
# Algeria              9.956086e+06
# Andorra              5.827721e+04
# Angola               6.074066e+06
#                          ...
# Wales                4.132861e+06
# Wallis and Futuna    9.142925e+03
# Yemen                4.794049e+05
# Zambia               1.048484e+06
# Zimbabwe             4.181618e+06
# Name: total_vaccinations, Length: 223, dtype: float64

# %%
vacciantion_rate = df.groupby('country').apply(lambda row: row['total_vaccinations_per_hundred'] / 1000)
vacciantion_rate
# Out:
# C:\Users\UMPO\AppData\Local\Temp\ipykernel_5472\2636423789.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   vacciantion_rate = df.groupby('country').apply(lambda row: row['total_vaccinations_per_hundred'] / 1000)
# country
# Afghanistan  0        0.00000
#              1            NaN
#              2            NaN
#              3            NaN
#              4            NaN
#                        ...
# Zimbabwe     86507    0.05759
#              86508    0.05825
#              86509    0.05861
#              86510    0.05920
#              86511    0.05990
# Name: total_vaccinations_per_hundred, Length: 86512, dtype: float64
