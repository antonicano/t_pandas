# %%
import pandas as pd

# %%
df = pd.read_csv('diabetes.csv')

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
df.shape
# Out:
# (768, 9)

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
df2 = df.copy()

# %%
df2.loc[2:5, 'Pregnancies'] = None

# %%
df2
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6.0      148             72             35        0  33.6
# 1            1.0       85             66             29        0  26.6
# 2            NaN      183             64              0        0  23.3
# 3            NaN       89             66             23       94  28.1
# 4            NaN      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763         10.0      101             76             48      180  32.9
# 764          2.0      122             70             27        0  36.8
# 765          5.0      121             72             23      112  26.2
# 766          1.0      126             60              0        0  30.1
# 767          1.0       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               764 non-null    float64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(3), int64(6)
# memory usage: 54.1 KB

# %%
df2.isnull().sum()
# Out:
# Pregnancies                 4
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
df.loc[df['BloodPressure']>100]
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 43             9      171            110             24      240  45.4
# 84             5      137            108              0        0  48.8
# 106            1       96            122              0        0  22.4
# 177            0      129            110             46      130  67.1
# 207            5      162            104              0        0  37.7
# 362            5      103            108             37        0  39.2
# 369            1      133            102             28      140  32.8
# 440            0      189            104             25        0  34.3
# 549            4      189            110             31        0  28.5
# 658           11      127            106              0        0  39.0
# 662            8      167            106             46      231  37.6
# 672           10       68            106             23       49  35.5
# ...

# %%
df_concat = pd.concat([df2, df])
df_concat
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6.0      148             72             35        0  33.6
# 1            1.0       85             66             29        0  26.6
# 2            NaN      183             64              0        0  23.3
# 3            NaN       89             66             23       94  28.1
# 4            NaN      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763         10.0      101             76             48      180  32.9
# 764          2.0      122             70             27        0  36.8
# 765          5.0      121             72             23      112  26.2
# 766          1.0      126             60              0        0  30.1
# 767          1.0       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df_concat = df_concat.reset_index(drop=True)
df_concat
# Out:
#       Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0             6.0      148             72             35        0  33.6
# 1             1.0       85             66             29        0  26.6
# 2             NaN      183             64              0        0  23.3
# 3             NaN       89             66             23       94  28.1
# 4             NaN      137             40             35      168  43.1
# ...           ...      ...            ...            ...      ...   ...
# 1531         10.0      101             76             48      180  32.9
# 1532          2.0      122             70             27        0  36.8
# 1533          5.0      121             72             23      112  26.2
# 1534          1.0      126             60              0        0  30.1
# 1535          1.0       93             70             31        0  30.4
#
#       DiabetesPedigreeFunction  Age  Outcome
# 0                        0.627   50        1
# ...

# %%
df['id'] = df.index

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome   id
# 0                       0.627   50        1    0
# ...

# %%
df_pregnancies = df[['id','Pregnancies']]
df_pregnancies
# Out:
#       id  Pregnancies
# 0      0            6
# 1      1            1
# 2      2            8
# 3      3            1
# 4      4            0
# ..   ...          ...
# 763  763           10
# 764  764            2
# 765  765            5
# 766  766            1
# 767  767            1
#
# [768 rows x 2 columns]

# %%
df_pregnancies = df_pregnancies.rename(columns={'id':'id_pregnant'})
df_pregnancies
# Out:
#      id_pregnant  Pregnancies
# 0              0            6
# 1              1            1
# 2              2            8
# 3              3            1
# 4              4            0
# ..           ...          ...
# 763          763           10
# 764          764            2
# 765          765            5
# 766          766            1
# 767          767            1
#
# [768 rows x 2 columns]

# %%
df = pd.read_csv('diabetes.csv')

# %%
df['Glucose_Insulin_Ratio'] = df['Glucose'] / df['Insulin']
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome  Glucose_Insulin_Ratio
# ...

# %%
df['Glucose_Insulin_Ratio_2'] = df.apply(lambda row: row['Glucose'] / row['Insulin'], axis = 1)
df
# Out:
# C:\Users\UMPO\AppData\Local\Temp\ipykernel_4284\77100447.py:1: RuntimeWarning: divide by zero encountered in scalar divide
#   df['Glucose_Insulin_Ratio_2'] = df.apply(lambda row: row['Glucose'] / row['Insulin'], axis = 1)
# C:\Users\UMPO\AppData\Local\Temp\ipykernel_4284\77100447.py:1: RuntimeWarning: invalid value encountered in scalar divide
#   df['Glucose_Insulin_Ratio_2'] = df.apply(lambda row: row['Glucose'] / row['Insulin'], axis = 1)
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# ...

# %%
(df.loc[0:10000,'Outcome']).value_counts(normalize=True)
# Out:
# Outcome
# 0    0.651042
# 1    0.348958
# Name: proportion, dtype: float64

# %%
df.value_counts(subset=['Pregnancies', 'Outcome'], sort=False, normalize=True)
# Out:
# Pregnancies  Outcome
# 0            0          0.095052
#              1          0.049479
# 1            0          0.138021
#              1          0.037760
# 2            0          0.109375
#              1          0.024740
# 3            0          0.062500
#              1          0.035156
# 4            0          0.058594
#              1          0.029948
# 5            0          0.046875
#              1          0.027344
# 6            0          0.044271
#              1          0.020833
# 7            0          0.026042
#              1          0.032552
# 8            0          0.020833
#              1          0.028646
# 9            0          0.013021
#              1          0.023438
# 10           0          0.018229
#              1          0.013021
# 11           0          0.005208
#              1          0.009115
# 12           0          0.006510
#              1          0.005208
# 13           0          0.006510
# ...

# %%
df.groupby('Outcome').mean()
# Out:
#          Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# Outcome
# 0           3.298000  109.980000      68.184000      19.664000   68.792000
# 1           4.865672  141.257463      70.824627      22.164179  100.335821
#
#                BMI  DiabetesPedigreeFunction        Age  \
# Outcome
# 0        30.304200                  0.429734  31.190000
# 1        35.142537                  0.550500  37.067164
#
#          Glucose_Insulin_Ratio  Glucose_Insulin_Ratio_2
# Outcome
# 0                          inf                      inf
# 1                          inf                      inf

# %%
df.groupby(['Pregnancies', 'Outcome']).mean()
# Out:
#                         Glucose  BloodPressure  SkinThickness     Insulin  \
# Pregnancies Outcome
# 0           0        111.945205      69.205479      21.054795   77.561644
#             1        144.236842      63.210526      24.605263   89.578947
# 1           0        104.254717      66.830189      23.047170   84.320755
#             1        143.793103      71.310345      29.517241  151.137931
# 2           0        105.214286      61.940476      20.107143   72.619048
#             1        135.473684      69.052632      28.210526  144.315789
# 3           0        109.604167      65.708333      17.520833   62.020833
#             1        148.444444      68.148148      24.629630  132.666667
# 4           0        117.555556      71.577778      18.422222   78.466667
#             1        139.913043      67.000000      10.913043   51.782609
# 5           0        111.666667      74.666667      17.166667   46.861111
# ...

# %%
import numpy as np

# %%
pd.pivot_table(df, values='BMI', index='Pregnancies', columns=['Outcome'],aggfunc=np.mean)
# Out:
# C:\Users\UMPO\AppData\Local\Temp\ipykernel_4284\1817412971.py:1: FutureWarning: The provided callable <function mean at 0x0000016C90C544A0> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   pd.pivot_table(df, values='BMI', index='Pregnancies', columns=['Outcome'],aggfunc=np.mean)
# Outcome              0          1
# Pregnancies
# 0            31.727397  39.213158
# 1            29.616038  37.793103
# 2            29.679762  34.578947
# 3            29.231250  32.548148
# 4            31.255556  33.873913
# 5            31.100000  36.780952
# 6            29.591176  31.775000
# 7            29.975000  34.756000
# 8            30.693750  32.204545
# 9            28.840000  33.300000
# 10           30.114286  31.380000
# 11           37.125000  39.385714
# 12           30.560000  34.575000
# 13           33.280000  36.720000
# ...
